# %% [markdown]
# # Here I will start a small scale analysis (of 6 months of 2007)
# This is bringing in some of the data organizing that I started with as well as some of the analysis that was experimented with in prior notebooks.

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# import libraries
import xml.etree.ElementTree as Et
import glob
import pandas as pd
import nltk
from nltk.corpus import stopwords
import string
import matplotlib.pyplot as plt
import pickle
from pprint import pprint
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import numpy as np
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
pd2007 = pickle.load(open("nyt-2007.p", "rb"))
pd2007.head()
# Out:
#      DOCID Date Month  Year                      Name  \
# 0  1815718    1     1  2007        BLUMENTHAL, MARTIN
# 0  1815719    1     1  2007         BRADLEY, CAROL L.
# 0  1815720    1     1  2007       CRAWFORD, PERRY JR.
# 0  1815721    1     1  2007     FLOOD, ROBERT FRANCIS
# 0  1815722    1     1  2007  GEISLER, ENID (FRIEDMAN)
#
#                                                 Text
# 0  blumenthal--martin. a new york business man an...
# 0  bradley--carol l., 84, of tinton falls, nj die...
# 0  crawford--perry jr., died at 89 on december 13...
# 0  flood--robert francis, husband of the late cat...
# 0  geisler--enid (friedman), on december 29, 2006...

# %%
pd2007_sorted = pd2007.groupby(['Name', 'DOCID']).count()

# %%
len(pd2007_sorted)
# Out:
# 53949

# %%
pd2007_sorted
# Out:
#                                   Date  Month  Year  Text
# Name                     DOCID
# .ROWN, SHERROD (SEN)     1844820     1      1     1     1
# 50 CENT                  1826921     1      1     1     1
# AALTO, ALVAR             1837135     1      1     1     1
# AALTO, ALVAR (1898-1976) 1837135     1      1     1     1
# AARON, DORA              1829159     1      1     1     1
# AARON, GEORGE            1834607     1      1     1     1
# AARON, HANK              1842448     1      1     1     1
#                          1844505     1      1     1     1
#                          1845058     1      1     1     1
#                          1846773     1      1     1     1
#                          1850704     1      1     1     1
#                          1850750     1      1     1     1
#                          1850950     1      1     1     1
#                          1855444     1      1     1     1
# AARON, KENNETH           1848150     1      1     1     1
# ...

# %% [markdown]
# ### Now I need to find names that are in multiple documents

# %%
pd2007_sorted.xs("AARON, HANK").index.values.tolist()
# Out:
# ['1842448',
#  '1844505',
#  '1845058',
#  '1846773',
#  '1850704',
#  '1850750',
#  '1850950',
#  '1855444']

# %%
#get a list of the names
names_2007 = list(pd2007["Name"])

# %%
# restructure multiple occurrences as a dictionary to list out what documents they are in
names_and_occurences = {}
for name in names_2007:
    names_and_occurences[name] = pd2007_sorted.xs(name).index.values.tolist()
pprint(names_and_occurences)
# Out:
# {'.ROWN, SHERROD (SEN)': ['1844820'],
#  '50 CENT': ['1826921'],
#  'AALTO, ALVAR': ['1837135'],
#  'AALTO, ALVAR (1898-1976)': ['1837135'],
#  'AARON, DORA': ['1829159'],
#  'AARON, GEORGE': ['1834607'],
#  'AARON, HANK': ['1842448',
#                  '1844505',
#                  '1845058',
#                  '1846773',
#                  '1850704',
#                  '1850750',
#                  '1850950',
#                  '1855444'],
#  'AARON, KENNETH': ['1848150'],
#  'AAYER, ABETHA': ['1846223'],
#  'ABAKANOWICZ, MAGDALENA': ['1821711'],
#  'ABANI, CHRIS': ['1822236'],
#  'ABAZIE, FRANKLIN': ['1836246'],
#  'ABBADO, CLAUDIO': ['1822635'],
#  'ABBAS, MAHMOUD': ['1817246',
#                     '1817374',
#                     '1819061',
#                     '1820018',
#                     '1824653',
#                     '1824944',
#                     '1825538',
#                     '1826354',
#                     '1826558',
#                     '1827378',
# ...

# %%
sia = SentimentIntensityAnalyzer()

for name in names_and_occurences:
    numdocs = len(names_and_occurences.get(name))
    neg = []
    neu = []
    pos = []
    for docid in names_and_occurences.get(name):
        row = pd2007.loc[pd2007['DOCID'] == docid]
        text = str(row['Text'])
        scores = sia.polarity_scores(text)
        neg.append(scores.get('neg'))
        neu.append(scores.get('neu'))
        pos.append(scores.get('pos'))
    pprint({'Name': name, 'Num_Docs': numdocs, 'NEG': np.mean(neg), 'NEU': np.mean(neu), 'POS': np.mean(pos)})
#     sent_scores = sent_scores.append([{'Name': name, 'Num_Docs': numdocs, 'NEG': np.mean(neg), 'NEU': np.mean(neu), 'POS': np.mean(pos)}])
# Out:
# {'NEG': 0.0,
#  'NEU': 1.0,
#  'Name': 'BLUMENTHAL, MARTIN',
#  'Num_Docs': 3,
#  'POS': 0.0}
# {'NEG': 0.0, 'NEU': 1.0, 'Name': 'BRADLEY, CAROL L.', 'Num_Docs': 1, 'POS': 0.0}
# {'NEG': 0.247,
#  'NEU': 0.753,
#  'Name': 'CRAWFORD, PERRY JR.',
#  'Num_Docs': 1,
#  'POS': 0.0}
# {'NEG': 0.0,
#  'NEU': 1.0,
#  'Name': 'FLOOD, ROBERT FRANCIS',
#  'Num_Docs': 1,
#  'POS': 0.0}
# {'NEG': 0.0,
#  'NEU': 1.0,
#  'Name': 'GEISLER, ENID (FRIEDMAN)',
#  'Num_Docs': 2,
#  'POS': 0.0}
# {'NEG': 0.26500000000000001,
#  'NEU': 0.73499999999999999,
#  'Name': 'GIUDICE, EMILY',
#  'Num_Docs': 1,
#  'POS': 0.0}
# {'NEG': 0.0, 'NEU': 1.0, 'Name': 'HIRSCH, TRUDE', 'Num_Docs': 1, 'POS': 0.0}
# {'NEG': 0.0,
#  'NEU': 1.0,
#  'Name': 'KERRIGAN, MARGARET H. M. (MIMI)',
#  'Num_Docs': 1,
#  'POS': 0.0}
# {'NEG': 0.0,
#  'NEU': 1.0,
#  'Name': 'KLEIN, ABRAHAM E., PH.D.',
#  'Num_Docs': 1,
#  'POS': 0.0}
# {'NEG': 0.26500000000000001,
#  'NEU': 0.73499999999999999,
# ...
