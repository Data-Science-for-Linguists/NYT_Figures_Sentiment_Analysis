# %% [markdown]
# # Data Cleaning and Processing
# - This small data set uses only 1 folder from the NYT Corpus
# - This is to make sure that the script works before scaling up to the entire corpus

# %%
# import libraries
import xml.etree.ElementTree as Et
import glob
import pandas as pd
import nltk

# %%
# create new dataframe with empty data
columns = ['Date', 'Month', 'Year', 'Name', 'Text']
data = pd.DataFrame(columns=columns)
data
# Out:
# Empty DataFrame
# Columns: [Date, Month, Year, Name, Text]
# Index: []

# %%
# open each xml file in the specified folder, open it and print out the names of mentioned people
for file in glob.glob("../data/NYT Corpus/nyt_corpus/data/2007/01/01/*.xml"):
    # parse the xml file into an element tree to extract data
    tree = Et.parse(file)
    root = tree.getroot()
    
    # get publication date information
    date = root.find(".//meta[@name='publication_day_of_month']").attrib['content']
    month = root.find(".//meta[@name='publication_month']").attrib['content']
    year = root.find(".//meta[@name='publication_year']").attrib['content']
    
    # get article text information
    # some articles seem to lack text - this is caught and handled in the if/else
    article = root.find(".//block[@class='full_text']/p")
    if article is not None:
        text = (article.text).lower()
    else:
        text = None
        
    # for each person mentioned, create a new row of data for them in the dataframe    
    for c in root.iter('person'):
        name = str(c.text).upper()
        data = data.append([{'Date': date, 'Month': month, 'Year': year, 'Name': name, 'Text': text}])
data
# Out:
#    Date Month  Year                                 Name  \
# 0     1     1  2007                   BLUMENTHAL, MARTIN
# 0     1     1  2007                    BRADLEY, CAROL L.
# 0     1     1  2007                  CRAWFORD, PERRY JR.
# 0     1     1  2007                FLOOD, ROBERT FRANCIS
# 0     1     1  2007             GEISLER, ENID (FRIEDMAN)
# 0     1     1  2007                       GIUDICE, EMILY
# 0     1     1  2007                        HIRSCH, TRUDE
# 0     1     1  2007      KERRIGAN, MARGARET H. M. (MIMI)
# 0     1     1  2007             KLEIN, ABRAHAM E., PH.D.
# 0     1     1  2007  LONG, WILLIAM ALBERS OF POTOMAC, MD
# 0     1     1  2007                LOSSIN, MICHAEL LOUIS
# 0     1     1  2007           MANHEIMER, ROBERT H., M.D.
# 0     1     1  2007                     MEYERS, NICHOLAS
# 0     1     1  2007               MUSKATT, HELEN (HENNY)
# 0     1     1  2007                 RIZZO, FRANK A. M.D.
# 0     1     1  2007                      ROSENBERG, EARL
# 0     1     1  2007                         SCIRE, HELEN
# 0     1     1  2007            SEEMAN, MILDRED ROTHSTEIN
# 0     1     1  2007                  SYMINGTON, MAUD LEE
# 0     1     1  2007                       BARISON, DAVID
# 0     1     1  2007                 DEIN, GITTIE PFEFFER
# 0     1     1  2007                         GENTRY, RICK
# 0     1     1  2007                      SCHEINMAN, ALAN
# 0     1     1  2007                         SILVA, FABIO
# 0     1     1  2007                       WRIGHT, ANDREW
# 0     1     1  2007                        TEDESCHI, BOB
# 0     1     1  2007                      HOLDEN, STEPHEN
# 0     1     1  2007                         SIMON, CARLY
# 0     1     1  2007                         SIMON, CARLY
# 0     1     1  2007                   TOMMASINI, ANTHONY
# ..  ...   ...   ...                                  ...
# 0     1     1  2007                 SPITZER, ELIOT (GOV)
# 0     1     1  2007                     SPITZER, ELIOT L
# 0     1     1  2007                 KIRKPATRICK, DAVID D
# 0     1     1  2007                        BURNS, JOHN F
# 0     1     1  2007                        SANTORA, MARC
# 0     1     1  2007                      HUSSEIN, SADDAM
# 0     1     1  2007   MALIKI, NURI KAMAL AL- (PRIME MIN)
# 0     1     1  2007                      HUSSEIN, SADDAM
# 0     1     1  2007               MALIKI, NURI KAMAL AL-
# 0     1     1  2007                  ARCHIBOLD, RANDAL C
# 0     1     1  2007                      COOPER, MICHAEL
# 0     1     1  2007                 SPITZER, ELIOT (GOV)
# 0     1     1  2007              SWEET, ROBERT W (JUDGE)
# 0     1     1  2007               PATAKI, GEORGE E (GOV)
# 0     1     1  2007                     SPITZER, ELIOT L
# 0     1     1  2007                     MEDINA, JENNIFER
# 0     1     1  2007                   RELL, M JODI (GOV)
# 0     1     1  2007                ROWLAND, JOHN G (GOV)
# 0     1     1  2007                         RELL, M JODI
# 0     1     1  2007                      ROWLAND, JOHN G
# 0     1     1  2007                        BUCKLEY, CARA
# 0     1     1  2007                   GETTLEMAN, JEFFREY
# 0     1     1  2007                      WILSON, MICHAEL
# 0     1     1  2007                       SOUTHERN, JOHN
# 0     1     1  2007                    WASHINGTON, EDWIN
# 0     1     1  2007                           SAPP, CORY
# 0     1     1  2007                      WILSON, MICHAEL
# 0     1     1  2007                       QUILES, ALEXIE
# 0     1     1  2007                        FAHIM, KAREEM
# 0     1     1  2007                        FAHIM, KAREEM
#
#                                                  Text
# 0   blumenthal--martin. a new york business man an...
# 0   bradley--carol l., 84, of tinton falls, nj die...
# 0   crawford--perry jr., died at 89 on december 13...
# 0   flood--robert francis, husband of the late cat...
# 0   geisler--enid (friedman), on december 29, 2006...
# 0   giudice--emily, 94 of ridgewood, nj died decem...
# 0   hirsch--trude, born in vienna, austria. belove...
# 0   kerrigan--margaret h. m. (mimi). december 28, ...
# 0   klein--abraham e., ph.d., professor emeritus, ...
# 0   long--william albers of potomac, md, died peac...
# 0   lossin--michael louis, on december 30, 2006. l...
# 0   manheimer--robert h., m.d. died after a short ...
# 0   meyers--nicholas, music supervisor and editor ...
# 0   muskatt--helen (henny), 86, on december 23rd. ...
# 0   rizzo--frank a. m.d. of tenafly, nj on decembe...
# 0   rosenberg--earl. we are deeply saddened by the...
# 0   scire--helen, new york freudian society mourns...
# 0   seeman--mildred rothstein, 94 or monroe townsh...
# 0   symington--maud lee, passed away on december 2...
# 0   barison--david. 1964--1995. ''life seems more ...
# 0   dein--gittie pfeffer. my dear sis loved and re...
# 0   gentry--rick. in memory of rick gentry, may 22...
# 0   scheinman--alan. happy birthday. we miss your ...
# 0   silva--fabio. all my love fabio, i do miss you...
# 0   for years, internet users have treated online ...
# 0   for years, internet users have treated online ...
# 0   entering the world of carly simon's new album ...
# 0   entering the world of carly simon's new album ...
# 0   entering the world of carly simon's new album ...
# 0   even before the metropolitan opera's saturday ...
# ..                                                ...
# 0   eliot laurence spitzer takes the oath of offic...
# 0   eliot laurence spitzer takes the oath of offic...
# 0   the democrats taking over congress this week a...
# 0   with his plain pine coffin strapped into an am...
# 0   with his plain pine coffin strapped into an am...
# 0   with his plain pine coffin strapped into an am...
# 0   with his plain pine coffin strapped into an am...
# 0   with his plain pine coffin strapped into an am...
# 0   with his plain pine coffin strapped into an am...
# 0   it may fall short of a feel-good sequel to ''c...
# 0   with his wife, his children and his parents lo...
# 0   with his wife, his children and his parents lo...
# 0   with his wife, his children and his parents lo...
# 0   with his wife, his children and his parents lo...
# 0   with his wife, his children and his parents lo...
# 0   as she wrote her first inaugural speech, m. jo...
# 0   as she wrote her first inaugural speech, m. jo...
# 0   as she wrote her first inaugural speech, m. jo...
# 0   as she wrote her first inaugural speech, m. jo...
# 0   as she wrote her first inaugural speech, m. jo...
# 0   in new york city, rapes, robberies and assault...
# 0   as fighting began to flare sunday around kisma...
# 0   a driver killed on saturday when his car flipp...
# 0   a driver killed on saturday when his car flipp...
# 0   a driver killed on saturday when his car flipp...
# 0   a driver killed on saturday when his car flipp...
# 0   a driver from new rochelle ran another vehicle...
# 0   a driver from new rochelle ran another vehicle...
# 0   one person was found dead after a fire tore th...
# 0   two people were killed and another person was ...
#
# [238 rows x 5 columns]
